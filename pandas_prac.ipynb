# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.3.3

# %%
my_dataset = {
    'Name': ['Alice', ' ', 'Charlie', 'David'],
    'Age': [24, 27, 22, 32],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston']
}

df = pd.DataFrame(my_dataset)
print(df)
# Out:
#       Name  Age         City
# 0    Alice   24     New York
# 1            27  Los Angeles
# 2  Charlie   22      Chicago
# 3    David   32      Houston

# %%
pd.Series(my_dataset['Name'])
# Out:
# 0      Alice
# 1
# 2    Charlie
# 3      David
# dtype: object

# %%
print(df)
print(df['Name'][0])
print(df['Age'][:])
# Out:
#       Name  Age         City
# 0    Alice   24     New York
# 1            27  Los Angeles
# 2  Charlie   22      Chicago
# 3    David   32      Houston
# Alice
# 0    24
# 1    27
# 2    22
# 3    32
# Name: Age, dtype: int64

# %%
df.index = ['a', 'b', 'c', 'd']
print(df)
# Out:
#       Name  Age         City
# a    Alice   24     New York
# b            27  Los Angeles
# c  Charlie   22      Chicago
# d    David   32      Houston

# %%
df = df.set_index('Name') ## column "name' as index
print(df)
# Out:
#          Age         City
# Name
# Alice     24     New York
#           27  Los Angeles
# Charlie   22      Chicago
# David     32      Houston

# %%
df
# Out:
#          Age         City
# Name
# Alice     24     New York
#           27  Los Angeles
# Charlie   22      Chicago
# David     32      Houston

# %%
print(df.loc[["Alice", "David"]])
# Out:
#        Age      City
# Name
# Alice   24  New York
# David   32   Houston

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df = df.reset_index()
print(df)
# Out:
#       Name  Age         City
# 0    Alice   24     New York
# 1            27  Los Angeles
# 2  Charlie   22      Chicago
# 3    David   32      Houston

# %%
print(df.loc[0: 2])
# Out:
#       Name  Age         City
# 0    Alice   24     New York
# 1            27  Los Angeles
# 2  Charlie   22      Chicago

# %%
print(df.loc[[0, 1, 2]])
# Out:
#       Name  Age         City
# 0    Alice   24     New York
# 1            27  Los Angeles
# 2  Charlie   22      Chicago

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df1 = pd.read_csv("all_medicine databased.csv")
df1.head()
# Out:
# C:\Users\mural\AppData\Local\Temp\ipykernel_14668\1397996569.py:1: DtypeWarning: Columns (42,43,44,45,46,47,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv("all_medicine databased.csv")
#    id                      name                     substitute0  \
# 0   1  augmentin 625 duo tablet  Penciclav 500 mg/125 mg Tablet
# 1   2       azithral 500 tablet         Zithrocare 500mg Tablet
# 2   3          ascoril ls syrup                 Solvin LS Syrup
# 3   4      allegra 120mg tablet                    Lcfex Tablet
# 4   5            avil 25 tablet              Eralet 25mg Tablet
#
#               substitute1              substitute2            substitute3  \
# 0  Moxikind-CV 625 Tablet  Moxiforce-CV 625 Tablet     Fightox 625 Tablet
# 1         Azax 500 Tablet          Zady 500 Tablet  Cazithro 500mg Tablet
# 2       Ambrodil-LX Syrup        Zerotuss XP Syrup         Capex LS Syrup
# ...

# %%
df.to_string()
# Out:
# '      Name  Age         City\n0    Alice   24     New York\n1            27  Los Angeles\n2  Charlie   22      Chicago\n3    David   32      Houston'

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248218 entries, 0 to 248217
# Data columns (total 58 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id                 248218 non-null  int64
#  1   name               248218 non-null  object
#  2   substitute0        238621 non-null  object
#  3   substitute1        233867 non-null  object
#  4   substitute2        230233 non-null  object
#  5   substitute3        226856 non-null  object
#  6   substitute4        223962 non-null  object
#  7   sideEffect0        248218 non-null  object
#  8   sideEffect1        238416 non-null  object
#  9   sideEffect2        229500 non-null  object
#  10  sideEffect3        207638 non-null  object
#  11  sideEffect4        163560 non-null  object
#  12  sideEffect5        131258 non-null  object
#  13  sideEffect6        91857 non-null   object
#  14  sideEffect7        67750 non-null   object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Age     4 non-null      int64
#  2   City    4 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 228.0+ bytes

# %%
new_df = df.dropna()
new_df.head()
# Out:
#       Name  Age         City
# 0    Alice   24     New York
# 1            27  Los Angeles
# 2  Charlie   22      Chicago
# 3    David   32      Houston

# %%
df.isna().sum()
# Out:
# Name    0
# Age     0
# City    0
# dtype: int64

# %%
import numpy as np

df["Name"] = df["Name"].replace(r'^\s*$', np.nan, regex=True)

# %%
df.fillna(method ='ffill', inplace=True)  #--> fills NaN values with the previous value in the column, bfill method --> fills NaN values with the next value in the column
print(df)
# Out:
#       Name  Age         City
# 0    Alice   24     New York
# 1  Charlie   27  Los Angeles
# 2  Charlie   22      Chicago
# 3    David   32      Houston
# C:\Users\mural\AppData\Local\Temp\ipykernel_14668\1305982807.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method ='ffill', inplace=True)  #--> fills NaN values with the previous value in the column, bfill method --> fills NaN values with the next value in the column

# %%
df
# Out:
#       Name  Age         City
# 0    Alice   24     New York
# 1  Charlie   27  Los Angeles
# 2  Charlie   22      Chicago
# 3    David   32      Houston

# %%
print(type(new_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.loc[1, 'Name'] = 'Bob'  #--> changing specific value in dataframe
print(df)
# Out:
#       Name   Age      City
# 0    Alice  24.0  New York
# 2  Charlie  22.0   Chicago
# 3    David  32.0   Houston
# 1      Bob   NaN       NaN

# %%
df.drop('1', inplace=True)  #--> drops the row with index 'Bob'

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#    index     Name   Age      City
# 0      0    Alice  24.0  New York
# 1      2  Charlie  22.0   Chicago
# 2      3    David  32.0   Houston
# 3      1      Bob   NaN       NaN

# %%
df.drop('index', axis=1, inplace=True)

# %%
df
# Out:
#       Name   Age      City
# 0    Alice  24.0  New York
# 1  Charlie  22.0   Chicago
# 2    David  32.0   Houston
# 3      Bob   NaN       NaN

# %%
df.loc[3, 'Age'] = 33
df.loc[3, 'City'] = 'San Francisco'
df
# Out:
#       Name   Age           City
# 0    Alice  24.0       New York
# 1  Charlie  22.0        Chicago
# 2    David  32.0        Houston
# 3      Bob  33.0  San Francisco

# %%
print(df1.duplicated())
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 248213    False
# 248214    False
# 248215    False
# 248216    False
# 248217    False
# Length: 248218, dtype: bool

# %%
new_df.corr(numeric_only=True)
# Out:
#      Age
# Age  1.0
